# %% [markdown]
# # Week 5 — Exercises
# ## Attribution practice
#
# Two exercises. Try them yourself; reference solutions in `solutions/`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shap
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
plt.style.use("../../assets/mplstyle/course.mplstyle")

# %% [markdown]
# ## Exercise 1 — SHAP dependence plot
#
# Train a GBM on California housing (you can copy from the lab). Use
# `shap.plots.scatter(sv[:, "MedInc"], color=sv)` to produce a **dependence plot** for
# `MedInc` — SHAP value of `MedInc` against the feature value, with another feature used
# for colour.
#
# Write one paragraph: what does the plot reveal about how the model uses median income?
# Is the relationship monotonic? Does its effect depend on a second feature?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Sanity-check Integrated Gradients
#
# Take the small CNN from the lab. Now build a **randomly initialised copy** (don't
# train it) and run IG on the same images. Compare side-by-side: trained-model
# attribution vs. random-model attribution.
#
# Write one paragraph: are the two attribution maps obviously different? What would it
# have meant for the lab figure if they looked the same?

# %%
# Your code here
