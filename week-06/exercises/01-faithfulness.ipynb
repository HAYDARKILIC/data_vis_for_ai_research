# %% [markdown]
# # Week 6 — Exercises
# ## Layer choice and the insertion metric
#
# Two exercises. Try them yourself; reference solutions in `solutions/`.

# %%
from pathlib import Path
import numpy as np
import torch
import torchvision
import torch.nn.functional as F
from PIL import Image
import matplotlib.pyplot as plt
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

plt.style.use("../../assets/mplstyle/course.mplstyle")
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

weights = torchvision.models.ResNet50_Weights.DEFAULT
model = torchvision.models.resnet50(weights=weights).to(DEVICE).eval()
preprocess = weights.transforms()
DATA = Path("../data")
IMG_PATHS = sorted(DATA.glob("*.jpg"))

# %% [markdown]
# ## Exercise 1 — Choosing the target layer
#
# Run Grad-CAM at **three different ResNet stages**: `layer2[-1]`, `layer3[-1]`, and
# `layer4[-1]`. Plot the resulting overlays side by side for one image.
#
# Write one paragraph: how does the spatial resolution and semantic specificity change
# across layers? Which layer would you choose for a paper figure, and why?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Insertion AUC
#
# Implement the **insertion** counterpart of the deletion curve from the lab. Start with
# a *blurred* image (use a 21×21 Gaussian blur). Iteratively replace pixels back to their
# original values in order of their Grad-CAM score (highest first). Plot the class
# probability vs. fraction of pixels inserted, and compute the AUC.
#
# Write one paragraph: insertion AUC is higher when the explanation is more faithful (the
# top-CAM pixels are *sufficient* to recover the prediction). On your test images, is
# Grad-CAM more faithful by the deletion metric, by the insertion metric, or by both
# equally?

# %%
# Your code here
