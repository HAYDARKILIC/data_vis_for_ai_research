# %% [markdown]
# # Week 3 — Exercises
# ## Diagnosing classifiers and regressors
#
# Two open problems.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer, fetch_california_housing
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
plt.style.use("../../assets/mplstyle/course.mplstyle")

# %% [markdown]
# ## Exercise 1 — Compare two classifiers with one diagnostic panel
#
# Train a `LogisticRegression` and a `GradientBoostingClassifier` on the breast-cancer
# dataset. Build a single figure with **two rows** (one per model) and **three columns**
# (ROC, PR, calibration). Add the AUC and AP in each panel's legend.
#
# Write one paragraph: which model would you ship and why? Reference at least one
# specific feature of one of the six panels in your reasoning.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Calibrate a miscalibrated classifier
#
# `RandomForestClassifier` is known to be under-confident. Train one on California housing
# turned into a binary classification problem (`y > median(y)`). Plot its calibration
# curve, then apply **isotonic** calibration (`sklearn.calibration.CalibratedClassifierCV`)
# and plot the calibration curve of the calibrated model on the same axes.
#
# Write one paragraph: did calibration help? Did the ROC AUC change?

# %%
# Your code here
