# %% [markdown]
# # Week 2 — Exercises
# ## Hyperparameter sensitivity in manifold learning
#
# Three problems. Try them yourself; reference solutions are in `solutions/`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE, trustworthiness
import umap
plt.style.use("../../assets/mplstyle/course.mplstyle")

img = np.load("../data/image_embeddings.npz", allow_pickle=True)
X, y, names = img["embeddings"], img["labels"], list(img["label_names"])
print(X.shape)

# %% [markdown]
# ## Exercise 1 — t-SNE perplexity grid on images
#
# Run t-SNE on the CIFAR-10 ResNet-18 embeddings with perplexities `[5, 30, 100, 500]`.
# Produce a 1×4 figure. For each subplot, also print the trustworthiness@10.
#
# Write one paragraph: which setting would you publish, and what does the lowest-perplexity
# panel teach you about reading t-SNE plots?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — UMAP with a different metric
#
# UMAP's default metric is Euclidean, but for normalized neural-network embeddings,
# **cosine** is often more appropriate. Run UMAP on the **text** embeddings with
# `metric="euclidean"` and again with `metric="cosine"`, with otherwise identical
# hyperparameters. Plot side by side.
#
# Write one paragraph: which gives more separable clusters, and why does the choice of
# metric matter for these particular vectors?

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Robustness to subsampling
#
# A common worry with t-SNE / UMAP is that the layout depends on the data sample.
# Subsample 50 % of the image embeddings five times, run UMAP on each subsample with a
# fixed `random_state`, and produce a 1×5 figure.
#
# Write one paragraph: which structural features are stable across subsamples, and which
# are not? Which features would you trust to interpret, and which would you not?

# %%
# Your code here
