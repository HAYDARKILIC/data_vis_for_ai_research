# %% [markdown]
# # Week 1 — Exercises
# ## Distributions and honest reporting
#
# Three open-ended problems on the LLM evaluation results table. Solutions are in
# `solutions/01-distributions-solutions.ipynb` — try the exercises yourself before peeking.
#
# Each exercise asks you to (a) produce one or two figures and (b) write one paragraph
# describing what the figure shows. The paragraph is the point; the figure is in service
# of it.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("../../assets/mplstyle/course.mplstyle")
df = pd.read_csv("../data/llm_eval_results.csv")
df.head()

# %% [markdown]
# ## Exercise 1 — Cost–accuracy trade-off (warm-up)
#
# Produce a figure that lets a researcher pick the **cheapest** model that achieves at
# least 70 % mean accuracy on `mmlu`. Encode `cost_per_1k_tokens` on a log axis and
# `accuracy` on a linear axis. Mark the 70 % horizontal threshold clearly.
#
# Write one paragraph: which model would you pick, and what does the chart tell you about
# the trade-off that a leaderboard table does not?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Rebuild the leaderboard, honestly
#
# The default leaderboard table reports one number per (model, benchmark). Reproduce that
# table — but then produce a **second** plot, in the small-multiples style, that shows
# the seed-level spread for each cell. Use either a strip plot or a violin.
#
# Write one paragraph: which models would you mark as "high variance" and why?

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Build a deliberately misleading chart, then fix it
#
# Build a chart that overstates a 1.5 percentage point accuracy gap between any two
# models you choose. Use a truncated y-axis, an aggressive aspect ratio, and a colour
# choice that hints "ours is better". Save it as `figures/misleading.png`.
#
# Then build the **fixed** version of the same chart with all of those decisions reversed.
# Save as `figures/honest.png`.
#
# Write one paragraph: which specific choices changed your subjective reading of the
# result?

# %%
# Your code here
