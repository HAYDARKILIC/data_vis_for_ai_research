# %% [markdown]
# # Week 4 — Exercises
# ## Reading a hyperparameter sweep
#
# These exercises use a **pre-computed** sweep CSV (`data/sweep_results.csv`) so you don't
# need a GPU or a long training run to do them. The CSV represents 60 trials of a
# hyperparameter search over `lr`, `weight_decay`, `batch_size`, `dropout`, and
# `optimizer`, with `val_loss` and `val_acc` as the recorded metrics.
#
# Your job is to **figure out from the chart which hyperparameters matter** — without
# peeking at the underlying simulation.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("../../assets/mplstyle/course.mplstyle")

sweep = pd.read_csv("../data/sweep_results.csv")
print(sweep.shape)
sweep.head()

# %% [markdown]
# ## Exercise 1 — Slice plot
#
# Produce a 1×5 figure: one subplot per hyperparameter (`lr`, `weight_decay`,
# `batch_size`, `dropout`, `optimizer`), with `val_loss` on the y-axis and the
# hyperparameter on the x-axis. Use a log scale for `lr` and `weight_decay`.
#
# Write one paragraph: which hyperparameters look like they matter? Which look noisy?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Parallel coordinates
#
# Build a parallel-coordinates plot with axes
# `[optimizer, lr, weight_decay, dropout, batch_size]` and lines coloured by `val_loss`.
# The implementation in the lab notebook (`parallel_coordinates(...)`) is fine to reuse —
# copy it over.
#
# Write one paragraph: how does the picture confirm or contradict your answer to
# exercise 1?

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Pick the next sweep
#
# Based on the two charts you just built, write a short specification (a few lines) for
# the **next** sweep. Which hyperparameter ranges would you keep, narrow, or fix? Which
# parameters would you spend a denser sweep on? Defend each decision in one sentence.

# %% [markdown]
# *(Write your answer in this Markdown cell.)*
